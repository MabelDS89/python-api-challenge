# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
import requests

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 655

# %%
#Perform API calls
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"

# Build query URL
query_url = url + "appid=" + weather_api_key + "&q=" + city

# Get weather data
weather_response = requests.get(query_url)
weather_json = weather_response.json()
print(weather_json)
# Out:
# {'coord': {'lon': -155.09, 'lat': 19.73}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 300.11, 'feels_like': 300.38, 'temp_min': 299.26, 'temp_max': 301.15, 'pressure': 1017, 'humidity': 58}, 'visibility': 10000, 'wind': {'speed': 3.6, 'deg': 330}, 'clouds': {'all': 1}, 'dt': 1596059642, 'sys': {'type': 1, 'id': 7881, 'country': 'US', 'sunrise': 1596038120, 'sunset': 1596085085}, 'timezone': -36000, 'id': 5855927, 'name': 'Hilo', 'cod': 200}

# %%
#Use a for loop to go through cities
#Use try and except for going through cities
query_url = url + "appid=" + weather_api_key + "&q="

#either make a dictionary to store key(city) and its values
lat = []
long =[]
max_temp = []
humidity = []
cloudiness = []
wind = []
country = []
date = []

city_name = []

for index,city in enumerate(cities):
    #try and except error
    try:
        response = requests.get(query_url + city).json()
        lat.append(response["coord"]["lat"])
        long.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind.append(response["wind"]["speed"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        city_name.append(city)
        print("City number is " + str(index) + " & city name is " + city)
    except:
        print("City not found")
# Out:
# City number is 0 & city name is saint-philippe
# City number is 1 & city name is barrow
# City number is 2 & city name is tasiilaq
# City number is 3 & city name is ziarat
# City number is 4 & city name is villeneuve-sur-lot
# City number is 5 & city name is aklavik
# City number is 6 & city name is bluff
# City number is 7 & city name is kodiak
# City number is 8 & city name is deputatskiy
# City number is 9 & city name is champerico
# City number is 10 & city name is vardo
# City number is 11 & city name is severo-kurilsk
# City number is 12 & city name is khatanga
# City number is 13 & city name is vaitape
# City number is 14 & city name is dunedin
# City not found
# City number is 16 & city name is ribeira grande
# City number is 17 & city name is ushuaia
# City number is 18 & city name is pietarsaari
# City number is 19 & city name is richards bay
# City number is 20 & city name is christchurch
# City number is 21 & city name is asau
# City number is 22 & city name is thompson
# City number is 23 & city name is kirensk
# City number is 24 & city name is sao filipe
# City number is 25 & city name is khowai
# City number is 26 & city name is puerto ayora
# City number is 27 & city name is victoria
# City number is 28 & city name is kongolo
# City number is 29 & city name is troitsko-pechorsk
# City number is 30 & city name is norman wells
# City not found
# City number is 32 & city name is albany
# City not found
# City not found
# City number is 35 & city name is coihaique
# City number is 36 & city name is whyalla
# City number is 37 & city name is katsuura
# City number is 38 & city name is bereda
# City number is 39 & city name is georgetown
# City number is 40 & city name is fortuna
# City number is 41 & city name is mataura
# City number is 42 & city name is bambous virieux
# City number is 43 & city name is arraial do cabo
# City number is 44 & city name is jalu
# City not found
# City number is 46 & city name is rikitea
# City number is 47 & city name is kahului
# City number is 48 & city name is constitucion
# City number is 49 & city name is vestmanna
# City not found
# City number is 51 & city name is porto novo
# City number is 52 & city name is harper
# City number is 53 & city name is xichang
# City number is 54 & city name is yellowknife
# City not found
# City number is 56 & city name is busselton
# City number is 57 & city name is saskylakh
# City number is 58 & city name is pangnirtung
# City number is 59 & city name is cape town
# City number is 60 & city name is souillac
# City number is 61 & city name is hilo
# City number is 62 & city name is castro
# City number is 63 & city name is ilulissat
# City number is 64 & city name is thohoyandou
# City number is 65 & city name is saldanha
# City number is 66 & city name is henties bay
# City number is 67 & city name is holesov
# City number is 68 & city name is luderitz
# City number is 69 & city name is banjar
# City number is 70 & city name is nyurba
# City number is 71 & city name is pinawa
# City number is 72 & city name is kropotkin
# City number is 73 & city name is sambava
# City number is 74 & city name is alta floresta
# City number is 75 & city name is oboyan
# City number is 76 & city name is jurm
# City number is 77 & city name is upernavik
# City number is 78 & city name is punta arenas
# City number is 79 & city name is agadez
# City number is 80 & city name is borba
# City number is 81 & city name is muros
# City number is 82 & city name is geraldton
# City not found
# City number is 84 & city name is beloha
# City number is 85 & city name is nanortalik
# City number is 86 & city name is bogorodskoye
# City number is 87 & city name is xinzhou
# City number is 88 & city name is pervomayskiy
# City number is 89 & city name is kununurra
# City number is 90 & city name is hithadhoo
# City number is 91 & city name is bredasdorp
# City number is 92 & city name is hermanus
# City number is 93 & city name is port hedland
# City number is 94 & city name is ahipara
# City number is 95 & city name is daro
# City number is 96 & city name is west bay
# City number is 97 & city name is bridlington
# City number is 98 & city name is bengkulu
# City number is 99 & city name is carnarvon
# City number is 100 & city name is chinhoyi
# City number is 101 & city name is lethem
# City number is 102 & city name is nikolskoye
# City number is 103 & city name is iqaluit
# City number is 104 & city name is zanjan
# City number is 105 & city name is shenjiamen
# City number is 106 & city name is dikson
# City number is 107 & city name is vaini
# City number is 108 & city name is biak
# City number is 109 & city name is okha
# City number is 110 & city name is klaksvik
# City number is 111 & city name is okakarara
# City number is 112 & city name is lagunas
# City number is 113 & city name is kapaa
# City number is 114 & city name is dekar
# City number is 115 & city name is qaanaaq
# City number is 116 & city name is faya
# City number is 117 & city name is waingapu
# City number is 118 & city name is east london
# City number is 119 & city name is mar del plata
# City number is 120 & city name is oskarshamn
# City number is 121 & city name is santa marta
# City number is 122 & city name is gornopravdinsk
# City number is 123 & city name is longyearbyen
# City number is 124 & city name is pointe michel
# City number is 125 & city name is atuona
# City number is 126 & city name is vinukonda
# City number is 127 & city name is masuguru
# City number is 128 & city name is itoman
# City number is 129 & city name is adrar
# City number is 130 & city name is sangar
# City number is 131 & city name is bathsheba
# City number is 132 & city name is hobart
# City not found
# City number is 134 & city name is baglung
# City number is 135 & city name is bud
# City number is 136 & city name is chiredzi
# City number is 137 & city name is guerrero negro
# City number is 138 & city name is huangnihe
# City number is 139 & city name is coquimbo
# City number is 140 & city name is klyuchi
# City number is 141 & city name is kudahuvadhoo
# City number is 142 & city name is rio gallegos
# City number is 143 & city name is coaldale
# City number is 144 & city name is comodoro rivadavia
# City number is 145 & city name is port hawkesbury
# City number is 146 & city name is kushima
# City number is 147 & city name is kutum
# City not found
# City number is 149 & city name is sayyan
# City number is 150 & city name is reconquista
# City number is 151 & city name is joshimath
# City number is 152 & city name is new plymouth
# City number is 153 & city name is balkanabat
# City number is 154 & city name is mobai
# City number is 155 & city name is chokurdakh
# City number is 156 & city name is tokoroa
# City number is 157 & city name is san carlos de bariloche
# City number is 158 & city name is camacupa
# City not found
# City number is 160 & city name is faanui
# City not found
# City number is 162 & city name is miraflores
# City number is 163 & city name is koratla
# City number is 164 & city name is nome
# City number is 165 & city name is port-cartier
# City number is 166 & city name is port augusta
# City number is 167 & city name is yasnyy
# City not found
# City not found
# City number is 170 & city name is santa luzia
# City number is 171 & city name is bedele
# City number is 172 & city name is alyangula
# City number is 173 & city name is airai
# City number is 174 & city name is padang
# City number is 175 & city name is aleksandrow kujawski
# City number is 176 & city name is yuci
# City number is 177 & city name is namibe
# City number is 178 & city name is tommot
# City number is 179 & city name is tuktoyaktuk
# City number is 180 & city name is albanel
# City number is 181 & city name is gunjur
# City number is 182 & city name is tuatapere
# City number is 183 & city name is hovd
# City number is 184 & city name is ostrovnoy
# City number is 185 & city name is waipawa
# City number is 186 & city name is laela
# City number is 187 & city name is erenhot
# City number is 188 & city name is wakkanai
# City number is 189 & city name is lebu
# City number is 190 & city name is alice springs
# City number is 191 & city name is dawlatabad
# City number is 192 & city name is beihai
# City number is 193 & city name is mount gambier
# City number is 194 & city name is egvekinot
# City number is 195 & city name is new norfolk
# City number is 196 & city name is jamestown
# City not found
# City number is 198 & city name is umm lajj
# City number is 199 & city name is port blair
# City number is 200 & city name is lavrentiya
# City not found
# City number is 202 & city name is avarua
# City number is 203 & city name is lubango
# City number is 204 & city name is aquiraz
# City not found
# City number is 206 & city name is shadegan
# City number is 207 & city name is ekhabi
# City number is 208 & city name is kavieng
# City number is 209 & city name is ponta do sol
# City number is 210 & city name is cidreira
# City number is 211 & city name is chapais
# City not found
# City number is 213 & city name is minab
# City number is 214 & city name is paducah
# City number is 215 & city name is namatanai
# City number is 216 & city name is yerbogachen
# City number is 217 & city name is kontagora
# City number is 218 & city name is cabo san lucas
# City number is 219 & city name is cayenne
# City not found
# City number is 221 & city name is marihatag
# City number is 222 & city name is mount isa
# City number is 223 & city name is seydi
# City number is 224 & city name is antropovo
# City number is 225 & city name is mushie
# City number is 226 & city name is payson
# City number is 227 & city name is pisco
# City number is 228 & city name is sebinkarahisar
# City number is 229 & city name is meadow lake
# City number is 230 & city name is anadyr
# City number is 231 & city name is baft
# City number is 232 & city name is vila velha
# City number is 233 & city name is flin flon
# City number is 234 & city name is savannah bight
# City number is 235 & city name is colares
# City number is 236 & city name is kenora
# City number is 237 & city name is chuy
# City number is 238 & city name is bambari
# City number is 239 & city name is osakarovka
# City number is 240 & city name is ha tinh
# City number is 241 & city name is vila franca do campo
# City number is 242 & city name is benjamin hill
# City number is 243 & city name is bartica
# City number is 244 & city name is crestview
# City number is 245 & city name is plouzane
# City number is 246 & city name is annau
# City number is 247 & city name is butaritari
# City number is 248 & city name is codrington
# City number is 249 & city name is nova odesa
# City number is 250 & city name is narsaq
# City number is 251 & city name is dudinka
# City number is 252 & city name is inuvik
# City number is 253 & city name is abu zabad
# City number is 254 & city name is kawalu
# City not found
# City number is 256 & city name is bethel
# City not found
# City number is 258 & city name is vilhena
# City number is 259 & city name is clyde river
# City number is 260 & city name is navalmoral de la mata
# City number is 261 & city name is ternate
# City number is 262 & city name is juneau
# City number is 263 & city name is port alfred
# City number is 264 & city name is la rochelle
# City number is 265 & city name is suntar
# City number is 266 & city name is mahebourg
# City number is 267 & city name is comarapa
# City not found
# City number is 269 & city name is boa vista
# City number is 270 & city name is tongliao
# City number is 271 & city name is lorengau
# City number is 272 & city name is khash
# City number is 273 & city name is kulhudhuffushi
# City number is 274 & city name is thinadhoo
# City number is 275 & city name is mata
# City number is 276 & city name is gao
# City number is 277 & city name is san juan
# City number is 278 & city name is tulum
# City number is 279 & city name is tiksi
# City not found
# City number is 281 & city name is yelizovo
# City number is 282 & city name is san patricio
# City number is 283 & city name is cobija
# City number is 284 & city name is corozal
# City not found
# City number is 286 & city name is auki
# City number is 287 & city name is price
# City number is 288 & city name is shumikha
# City number is 289 & city name is cherskiy
# City number is 290 & city name is lompoc
# City number is 291 & city name is pontianak
# City number is 292 & city name is tilichiki
# City number is 293 & city name is ankang
# City number is 294 & city name is malente
# City not found
# City number is 296 & city name is emba
# City number is 297 & city name is chitral
# City number is 298 & city name is fare
# City number is 299 & city name is merauke
# City number is 300 & city name is pishin
# City number is 301 & city name is isangel
# City number is 302 & city name is tazovskiy
# City number is 303 & city name is idrinskoye
# City number is 304 & city name is abadan
# City number is 305 & city name is stornoway
# City number is 306 & city name is mikhaylovka
# City number is 307 & city name is atambua
# City number is 308 & city name is charters towers
# City number is 309 & city name is mandiana
# City number is 310 & city name is tibiri
# City number is 311 & city name is naze
# City number is 312 & city name is arandis
# City number is 313 & city name is gushikawa
# City number is 314 & city name is novopokrovka
# City number is 315 & city name is husavik
# City number is 316 & city name is teluk nibung
# City number is 317 & city name is moissala
# City not found
# City number is 319 & city name is anchorage
# City number is 320 & city name is mildura
# City number is 321 & city name is camana
# City number is 322 & city name is mindelo
# City number is 323 & city name is port elizabeth
# City number is 324 & city name is colac
# City number is 325 & city name is wajima
# City number is 326 & city name is hualmay
# City number is 327 & city name is poum
# City number is 328 & city name is katrineholm
# City number is 329 & city name is doha
# City number is 330 & city name is vyazemskiy
# City number is 331 & city name is acapulco
# City number is 332 & city name is sechura
# City number is 333 & city name is lata
# City number is 334 & city name is caravelas
# City number is 335 & city name is honiara
# City number is 336 & city name is bandarbeyla
# City number is 337 & city name is arlit
# City number is 338 & city name is buala
# City number is 339 & city name is mantua
# City number is 340 & city name is san vicente
# City number is 341 & city name is yar-sale
# City number is 342 & city name is salalah
# City number is 343 & city name is zonguldak
# City not found
# City number is 345 & city name is dighwara
# City number is 346 & city name is kandalaksha
# City number is 347 & city name is tabas
# City number is 348 & city name is sinnamary
# City number is 349 & city name is palmer
# City number is 350 & city name is ust-kulom
# City number is 351 & city name is ketchikan
# City number is 352 & city name is serebryanyy bor
# City not found
# City number is 354 & city name is idlib
# City number is 355 & city name is alofi
# City number is 356 & city name is floro
# City not found
# City number is 358 & city name is esperance
# City number is 359 & city name is sydney
# City number is 360 & city name is aksu
# City number is 361 & city name is lianran
# City number is 362 & city name is novyy urengoy
# City number is 363 & city name is ciudad bolivar
# City number is 364 & city name is moba
# City number is 365 & city name is moranbah
# City number is 366 & city name is vila do maio
# City number is 367 & city name is kuching
# City number is 368 & city name is saint anthony
# City number is 369 & city name is la rioja
# City number is 370 & city name is sao joao da barra
# City number is 371 & city name is pirot
# City number is 372 & city name is wasilla
# City number is 373 & city name is flinders
# City number is 374 & city name is salamiyah
# City number is 375 & city name is mogadishu
# City number is 376 & city name is kaeo
# City number is 377 & city name is macduff
# City not found
# City number is 379 & city name is sistranda
# City number is 380 & city name is gravdal
# City number is 381 & city name is saint-francois
# City number is 382 & city name is mareeba
# City number is 383 & city name is bergerac
# City number is 384 & city name is miri
# City number is 385 & city name is galveston
# City not found
# City number is 387 & city name is north branch
# City number is 388 & city name is moose factory
# City number is 389 & city name is barra
# City number is 390 & city name is iquique
# City number is 391 & city name is bintulu
# City number is 392 & city name is touros
# City not found
# City number is 394 & city name is dingle
# City number is 395 & city name is quatre cocos
# City number is 396 & city name is ornskoldsvik
# City number is 397 & city name is bonavista
# City number is 398 & city name is roald
# City number is 399 & city name is puerto madero
# City number is 400 & city name is evans
# City number is 401 & city name is birobidzhan
# City number is 402 & city name is kruisfontein
# City number is 403 & city name is muisne
# City number is 404 & city name is udachnyy
# City number is 405 & city name is kaitangata
# City number is 406 & city name is pathalgaon
# City number is 407 & city name is lakewood
# City number is 408 & city name is kavaratti
# City number is 409 & city name is solnechnyy
# City number is 410 & city name is kribi
# City number is 411 & city name is tolmezzo
# City number is 412 & city name is pemangkat
# City number is 413 & city name is mitsamiouli
# City number is 414 & city name is tsuyama
# City number is 415 & city name is mayor pablo lagerenza
# City number is 416 & city name is teahupoo
# City number is 417 & city name is broome
# City number is 418 & city name is goldsboro
# City number is 419 & city name is urucui
# City number is 420 & city name is rincon
# City number is 421 & city name is sitka
# City number is 422 & city name is illapel
# City number is 423 & city name is butembo
# City number is 424 & city name is saint george
# City not found
# City number is 426 & city name is talnakh
# City not found
# City not found
# City number is 429 & city name is ancud
# City number is 430 & city name is varhaug
# City number is 431 & city name is krasnoborsk
# City number is 432 & city name is sur
# City number is 433 & city name is ornes
# City not found
# City number is 435 & city name is andenes
# City number is 436 & city name is santa isabel
# City number is 437 & city name is kabanjahe
# City number is 438 & city name is zhezkazgan
# City number is 439 & city name is batagay
# City number is 440 & city name is taoudenni
# City number is 441 & city name is saint-augustin
# City number is 442 & city name is sulangan
# City number is 443 & city name is los llanos de aridane
# City number is 444 & city name is okhotsk
# City number is 445 & city name is palana
# City number is 446 & city name is mitchell
# City number is 447 & city name is oyem
# City number is 448 & city name is eldorado
# City number is 449 & city name is dzemul
# City number is 450 & city name is torit
# City number is 451 & city name is marfino
# City number is 452 & city name is baherden
# City number is 453 & city name is carlagan
# City number is 454 & city name is arinos
# City number is 455 & city name is nileshwar
# City number is 456 & city name is cedar city
# City number is 457 & city name is miandrivazo
# City number is 458 & city name is homer
# City number is 459 & city name is esna
# City number is 460 & city name is kodinsk
# City number is 461 & city name is kerman
# City number is 462 & city name is general pico
# City number is 463 & city name is mezen
# City number is 464 & city name is aykhal
# City number is 465 & city name is tinqueux
# City number is 466 & city name is tullow
# City number is 467 & city name is lagoa
# City number is 468 & city name is athabasca
# City number is 469 & city name is katobu
# City number is 470 & city name is tongling
# City number is 471 & city name is huarmey
# City number is 472 & city name is tuburan
# City number is 473 & city name is havoysund
# City number is 474 & city name is paamiut
# City number is 475 & city name is lufilufi
# City number is 476 & city name is tual
# City number is 477 & city name is abha
# City number is 478 & city name is lokosovo
# City number is 479 & city name is jinchang
# City number is 480 & city name is formosa
# City number is 481 & city name is ola
# City number is 482 & city name is melenci
# City number is 483 & city name is majene
# City number is 484 & city name is florianopolis
# City number is 485 & city name is dalbandin
# City not found
# City number is 487 & city name is copainala
# City number is 488 & city name is port hardy
# City number is 489 & city name is berlevag
# City number is 490 & city name is brigantine
# City number is 491 & city name is qaqortoq
# City number is 492 & city name is port lincoln
# City not found
# City number is 494 & city name is paita
# City number is 495 & city name is provideniya
# City number is 496 & city name is mafinga
# City number is 497 & city name is vao
# City number is 498 & city name is grand-santi
# City number is 499 & city name is artsyz
# City number is 500 & city name is cockburn town
# City number is 501 & city name is halifax
# City number is 502 & city name is huangmei
# City number is 503 & city name is thunder bay
# City number is 504 & city name is aygehovit
# City number is 505 & city name is mweka
# City not found
# City number is 507 & city name is general roca
# City number is 508 & city name is salta
# City number is 509 & city name is samfya
# City number is 510 & city name is san cristobal
# City number is 511 & city name is santa rosa
# City number is 512 & city name is yumen
# City number is 513 & city name is rocha
# City number is 514 & city name is cooma
# City number is 515 & city name is pevek
# City number is 516 & city name is la ronge
# City number is 517 & city name is bilma
# City number is 518 & city name is sahuaripa
# City number is 519 & city name is jiujiang
# City number is 520 & city name is sebastian
# City number is 521 & city name is cubara
# City number is 522 & city name is axim
# City number is 523 & city name is ust-tsilma
# City number is 524 & city name is yulara
# City number is 525 & city name is kieta
# City number is 526 & city name is zyryanka
# City number is 527 & city name is lamar
# City not found
# City number is 529 & city name is mayo
# City number is 530 & city name is samarai
# City number is 531 & city name is anjozorobe
# City not found
# City number is 533 & city name is cozumel
# City number is 534 & city name is hofn
# City number is 535 & city name is rio grande
# City number is 536 & city name is shelburne
# City number is 537 & city name is itaituba
# City not found
# City number is 539 & city name is bowen
# City not found
# City number is 541 & city name is saint-joseph
# City number is 542 & city name is tarko-sale
# City number is 543 & city name is panzhihua
# City not found
# City number is 545 & city name is ambulu
# City number is 546 & city name is torbay
# City number is 547 & city name is luanda
# City number is 548 & city name is grafton
# City number is 549 & city name is surt
# City number is 550 & city name is nouadhibou
# City number is 551 & city name is liku
# City number is 552 & city name is raudeberg
# City number is 553 & city name is roura
# City number is 554 & city name is candolim
# City number is 555 & city name is prince rupert
# City not found
# City number is 557 & city name is nador
# City number is 558 & city name is piet retief
# City number is 559 & city name is vagur
# City not found
# City number is 561 & city name is kunda
# City number is 562 & city name is fukue
# City number is 563 & city name is pestravka
# City number is 564 & city name is manga
# City number is 565 & city name is piedade
# City number is 566 & city name is manta
# City number is 567 & city name is davila
# City number is 568 & city name is kibala
# City number is 569 & city name is asola
# City number is 570 & city name is quepos
# City number is 571 & city name is sampit
# City number is 572 & city name is borger
# City number is 573 & city name is hami
# City number is 574 & city name is byron bay
# City not found
# City number is 576 & city name is bandundu
# City number is 577 & city name is teknaf
# City not found
# City number is 579 & city name is bubaque
# City number is 580 & city name is aksha
# City number is 581 & city name is centralia
# City number is 582 & city name is fez
# City number is 583 & city name is dwarka
# City number is 584 & city name is tairua
# City number is 585 & city name is yichang
# City not found
# City number is 587 & city name is misratah
# City number is 588 & city name is ascension
# City number is 589 & city name is olafsvik
# City number is 590 & city name is myitkyina
# City number is 591 & city name is lagos
# City number is 592 & city name is spitak
# City number is 593 & city name is hobyo
# City number is 594 & city name is gongzhuling
# City number is 595 & city name is veraval
# City number is 596 & city name is cochrane
# City number is 597 & city name is la serena
# City number is 598 & city name is urucara
# City number is 599 & city name is honningsvag
# City number is 600 & city name is te anau
# City number is 601 & city name is ridgecrest
# City number is 602 & city name is kedougou
# City number is 603 & city name is kyra
# City number is 604 & city name is northam
# City number is 605 & city name is grand gaube
# City number is 606 & city name is uruguaiana
# City number is 607 & city name is diffa
# City number is 608 & city name is mehamn
# City number is 609 & city name is argayash
# City number is 610 & city name is oistins
# City number is 611 & city name is mahajanga
# City not found
# City number is 613 & city name is wuhan
# City number is 614 & city name is franklin
# City number is 615 & city name is hearst
# City number is 616 & city name is vikhorevka
# City number is 617 & city name is cabedelo
# City number is 618 & city name is hambantota
# City number is 619 & city name is ilheus
# City number is 620 & city name is tura
# City number is 621 & city name is san nicolas
# City number is 622 & city name is carauari
# City number is 623 & city name is ginir
# City number is 624 & city name is sorong
# City number is 625 & city name is kralendijk
# City number is 626 & city name is belyy yar
# City number is 627 & city name is porto nacional
# City number is 628 & city name is outram
# City number is 629 & city name is weligama
# City number is 630 & city name is atar
# City not found
# City number is 632 & city name is rawson
# City number is 633 & city name is kimparana
# City number is 634 & city name is eureka
# City number is 635 & city name is makat
# City number is 636 & city name is takaka
# City number is 637 & city name is bonito
# City number is 638 & city name is fort nelson
# City number is 639 & city name is tallahassee
# City number is 640 & city name is masallatah
# City number is 641 & city name is kesinga
# City number is 642 & city name is kloulklubed
# City number is 643 & city name is baykit
# City number is 644 & city name is odawara
# City number is 645 & city name is vestmannaeyjar
# City number is 646 & city name is daru
# City number is 647 & city name is mackay
# City number is 648 & city name is waddan
# City number is 649 & city name is basoko
# City number is 650 & city name is loreto
# City number is 651 & city name is pozo colorado
# City number is 652 & city name is tabuk
# City number is 653 & city name is soverato
# City number is 654 & city name is cap malheureux

# %%
#Create DataFrame
weather_df = pd.DataFrame({"City": city_name, "Lat": lat, "Lng": long,
                           "Max Temp": max_temp, "Humidity": humidity,
                           "Cloudiness": cloudiness, "Wind Speed": wind,
                           "Country": country, "Date": date})
weather_df
# Out:
#                    City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        saint-philippe -21.36   55.77    292.15        88           8
# 1                barrow  71.29 -156.79    280.15        81          90
# 2              tasiilaq  65.61  -37.64    280.15        70          71
# 3                ziarat  30.38   67.73    292.71        62          17
# 4    villeneuve-sur-lot  44.50    0.67    297.59        64           0
# ..                  ...    ...     ...       ...       ...         ...
# 599              loreto  22.27 -101.97    294.64        63         100
# 600       pozo colorado -23.49  -58.80    288.38        36          98
# 601               tabuk  17.42  121.44    296.93        90          99
# 602            soverato  38.69   16.55    298.15        88           0
# 603      cap malheureux -19.98   57.61    294.82        77          44
#
#      Wind Speed Country        Date
# 0          2.10      RE  1596059700
# 1         11.30      US  1596059632
# 2          3.10      GL  1596059644
# 3          1.50      PK  1596059700
# 4          1.00      FR  1596059700
# ..          ...     ...         ...
# 599        2.84      MX  1596059768
# 600        2.33      PY  1596059768
# 601        1.00      PH  1596059768
# 602        0.50      IT  1596059768
# 603        2.68      MU  1596059768
#
# [604 rows x 9 columns]

# %%
#Check which cities have humidity > 100%
humidity_df = weather_df.loc[weather_df["Humidity"] > 100]
humidity_df
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %% [markdown]
# There are no cities with humidity > 100%.

# %%
#Export DataFrame to CSV
weather_df.to_csv("output_data/cities.csv")

# %% [markdown]
# # Latitude vs. Temperature Plot

# %%
x = lat
y = max_temp

plt.scatter(lat, max_temp, marker="o", facecolors="lightblue", edgecolors="black")

#Add title and other labels
plt.title("City Latitude vs. Max Temperature (07/29/2020)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.savefig("output_data/Lat_Temp_Plot.png")
plt.show()

# %% [markdown]
# The Latitude vs. Temperature plot shows...

# %% [markdown]
# # Latitude vs. Humidity Plot

# %%
x = lat
y = humidity

plt.scatter(lat, humidity, marker="o", facecolors="lightblue", edgecolors="black")

#Add title and other labels
plt.title("City Latitude vs. humidity (07/29/2020)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.savefig("output_data/Lat_Humidity_Plot.png")
plt.show()

# %% [markdown]
# The Latitude vs. Humidity plot shows ...

# %% [markdown]
# # Latitude vs. Cloudiness Plot

# %%
x = lat
y = cloudiness

plt.scatter(lat, cloudiness, marker="o", facecolors="lightblue", edgecolors="black")

#Add title and other labels
plt.title("City Latitude vs. Cloudiness (07/29/2020)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.savefig("output_data/Lat_Cloudiness_Plot.png")
plt.show()

# %% [markdown]
# The Latitude vs. Cloudiness plot shows...

# %% [markdown]
# # Latitude vs. Wind Speed Plot

# %%
x = lat
y = wind

plt.scatter(lat, wind, marker="o", facecolors="lightblue", edgecolors="black")

#Add title and other labels
plt.title("City Latitude vs. Wind Speed (07/29/2020)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.savefig("output_data/Lat_Wind_Plot.png")
plt.show()

# %% [markdown]
# The Latitude vs. Wind Speed plot shows...

# %% [markdown]
# # LINEAR REGRESSIONS

# %%
#Create Northern Hemisphere DataFrames
northern_df = weather_df.loc[weather_df["Lat"] >= 0]
northern_df
# Out:
#                    City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 1                barrow  71.29 -156.79    280.15        81          90
# 2              tasiilaq  65.61  -37.64    280.15        70          71
# 3                ziarat  30.38   67.73    292.71        62          17
# 4    villeneuve-sur-lot  44.50    0.67    297.59        64           0
# 5               aklavik  68.22 -135.01    285.15        81          75
# ..                  ...    ...     ...       ...       ...         ...
# 597              waddan  29.16   16.14    298.70        51           0
# 598              basoko   1.24   23.62    296.10        87          83
# 599              loreto  22.27 -101.97    294.64        63         100
# 601               tabuk  17.42  121.44    296.93        90          99
# 602            soverato  38.69   16.55    298.15        88           0
#
#      Wind Speed Country        Date
# 1         11.30      US  1596059632
# 2          3.10      GL  1596059644
# 3          1.50      PK  1596059700
# 4          1.00      FR  1596059700
# 5          1.50      CA  1596059618
# ..          ...     ...         ...
# 597        8.22      LY  1596059767
# 598        1.77      CD  1596059767
# 599        2.84      MX  1596059768
# 601        1.00      PH  1596059768
# 602        0.50      IT  1596059768
#
# [413 rows x 9 columns]

# %%
#Create Southern Hemisphere DataFrames
southern_df = weather_df.loc[weather_df["Lat"] <= 0]
southern_df
# Out:
#                City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0    saint-philippe -21.36   55.77    292.15        88           8
# 6             bluff -46.60  168.33    284.67        75         100
# 13          vaitape -16.52 -151.75    300.03        77         100
# 14          dunedin -45.87  170.50    282.04        76          99
# 16          ushuaia -54.80  -68.30    277.15        92          75
# ..              ...    ...     ...       ...       ...         ...
# 586          bonito -21.12  -56.48    286.95        65          43
# 595            daru  -9.08  143.21    297.47        85         100
# 596          mackay -21.15  149.20    285.37        93           0
# 600   pozo colorado -23.49  -58.80    288.38        36          98
# 603  cap malheureux -19.98   57.61    294.82        77          44
#
#      Wind Speed Country        Date
# 0          2.10      RE  1596059700
# 6          6.21      NZ  1596059700
# 13         8.42      PF  1596059701
# 14         2.24      NZ  1596059419
# 16        12.90      AR  1596059624
# ..          ...     ...         ...
# 586        2.85      BR  1596059766
# 595        8.05      PG  1596059698
# 596        3.10      AU  1596059767
# 600        2.33      PY  1596059768
# 603        2.68      MU  1596059768
#
# [191 rows x 9 columns]

# %% [markdown]
# # Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northern_df["Lat"]
y_values = northern_df["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values, marker="o", facecolors="lightblue", edgecolors="black")

plt.plot(x_values,regress_values,"r-")

plt.annotate(line_eq,(6,0),fontsize=15,color="red")

#Add title and other labels
plt.title("Northern Hemisphere: City Latitude vs. Max Temperature (07/29/2020)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Show and save plot
plt.savefig("output_data/North_Lat_Temp_Plot.png")
plt.show()
# Out:
# The r-squared is: 0.4542194794769661

# %% [markdown]
# # Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_df["Lat"]
y_values = southern_df["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values, marker="o", facecolors="lightblue", edgecolors="black")

plt.plot(x_values,regress_values,"r-")

plt.annotate(line_eq,(6,0),fontsize=15,color="red")

#Add title and other labels
plt.title("Southern Hemisphere: City Latitude vs. Max Temperature (07/29/2020)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Show and save plot
plt.savefig("output_data/South_Lat_Temp_Plot.png")
plt.show()
# Out:
# The r-squared is: 0.6456213745011237
