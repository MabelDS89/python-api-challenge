# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
import requests

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 614

# %%
#Perform API calls
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"

# Build query URL
query_url = url + "appid=" + weather_api_key + "&q=" + city

# Get weather data
weather_response = requests.get(query_url)
weather_json = weather_response.json()
print(weather_json)
# Out:
# {'coord': {'lon': 114.16, 'lat': 22.29}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 301.45, 'feels_like': 305.88, 'temp_min': 300.37, 'temp_max': 302.04, 'pressure': 1007, 'humidity': 79}, 'visibility': 10000, 'wind': {'speed': 2.24, 'deg': 100}, 'rain': {'1h': 0.22}, 'clouds': {'all': 100}, 'dt': 1596053916, 'sys': {'type': 3, 'id': 47808, 'country': 'HK', 'sunrise': 1596059663, 'sunset': 1596107101}, 'timezone': 28800, 'id': 1819729, 'name': 'Hong Kong', 'cod': 200}

# %%
#Use a for loop to go through cities
#Use try and except for going through cities
query_url = url + "appid=" + weather_api_key + "&q="

#either make a dictionary to store key(city) and its values
lat = []
long =[]
max_temp = []
humidity = []
cloudiness = []
wind = []
country = []
date = []

city_name = []

for index,city in enumerate(cities):
    #try and except error
    try:
        response = requests.get(query_url + city).json()
        lat.append(response["coord"]["lat"])
        long.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind.append(response["wind"]["speed"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        city_name.append(city)
        print("City number is " + str(index) + " & city name is " + city)
    except:
        print("City not found")
# Out:
# City not found
# City not found
# City number is 2 & city name is provideniya
# City not found
# City not found
# City number is 5 & city name is hobart
# City number is 6 & city name is chokurdakh
# City number is 7 & city name is mataura
# City number is 8 & city name is cabedelo
# City number is 9 & city name is lima
# City number is 10 & city name is ayan
# City number is 11 & city name is broken hill
# City number is 12 & city name is ushuaia
# City not found
# City number is 14 & city name is rotifunk
# City number is 15 & city name is pevek
# City number is 16 & city name is busselton
# City number is 17 & city name is zhumadian
# City number is 18 & city name is port hedland
# City number is 19 & city name is vardo
# City not found
# City number is 21 & city name is carnarvon
# City number is 22 & city name is castro
# City number is 23 & city name is georgetown
# City number is 24 & city name is rio grande
# City number is 25 & city name is cape town
# City number is 26 & city name is qaanaaq
# City number is 27 & city name is malanje
# City number is 28 & city name is black river
# City number is 29 & city name is ixtapa
# City number is 30 & city name is port alfred
# City number is 31 & city name is kontagora
# City number is 32 & city name is wagar
# City number is 33 & city name is atuona
# City not found
# City number is 35 & city name is sinnamary
# City number is 36 & city name is ostrovnoy
# City number is 37 & city name is rikitea
# City number is 38 & city name is lorengau
# City number is 39 & city name is mareeba
# City number is 40 & city name is bada
# City number is 41 & city name is hilo
# City not found
# City number is 43 & city name is tahara
# City number is 44 & city name is new norfolk
# City number is 45 & city name is norman wells
# City number is 46 & city name is maragogi
# City number is 47 & city name is caernarfon
# City number is 48 & city name is korla
# City number is 49 & city name is avarua
# City number is 50 & city name is havre-saint-pierre
# City number is 51 & city name is gemena
# City number is 52 & city name is alberton
# City number is 53 & city name is ust-maya
# City not found
# City number is 55 & city name is arraial do cabo
# City number is 56 & city name is canon city
# City number is 57 & city name is thompson
# City number is 58 & city name is kodiak
# City number is 59 & city name is butaritari
# City number is 60 & city name is leningradskiy
# City number is 61 & city name is huilong
# City number is 62 & city name is haicheng
# City number is 63 & city name is sioux lookout
# City number is 64 & city name is verkh-usugli
# City number is 65 & city name is tasiilaq
# City number is 66 & city name is saskylakh
# City number is 67 & city name is mahon
# City not found
# City number is 69 & city name is lompoc
# City number is 70 & city name is punta arenas
# City number is 71 & city name is altay
# City number is 72 & city name is luoyang
# City number is 73 & city name is bacolod
# City number is 74 & city name is puerto ayora
# City number is 75 & city name is alpena
# City number is 76 & city name is zhigansk
# City number is 77 & city name is mar del plata
# City number is 78 & city name is manzanillo
# City number is 79 & city name is khatanga
# City number is 80 & city name is boden
# City number is 81 & city name is albany
# City number is 82 & city name is ribeira grande
# City not found
# City number is 84 & city name is svetlogorsk
# City not found
# City number is 86 & city name is bluff
# City number is 87 & city name is teguise
# City number is 88 & city name is hithadhoo
# City not found
# City not found
# City number is 91 & city name is torbay
# City number is 92 & city name is barrow
# City not found
# City number is 94 & city name is thinadhoo
# City number is 95 & city name is katsuura
# City number is 96 & city name is airai
# City number is 97 & city name is bethel
# City not found
# City number is 99 & city name is chino valley
# City number is 100 & city name is biltine
# City number is 101 & city name is jamestown
# City number is 102 & city name is mahebourg
# City number is 103 & city name is yellowknife
# City not found
# City not found
# City number is 106 & city name is kavaratti
# City not found
# City number is 108 & city name is cidreira
# City number is 109 & city name is east london
# City number is 110 & city name is petropavlovsk-kamchatskiy
# City number is 111 & city name is saint-philippe
# City number is 112 & city name is kaitangata
# City number is 113 & city name is esperance
# City number is 114 & city name is hermanus
# City number is 115 & city name is bani walid
# City number is 116 & city name is sao filipe
# City number is 117 & city name is vaini
# City number is 118 & city name is verkhniy avzyan
# City number is 119 & city name is erdenet
# City number is 120 & city name is porto novo
# City not found
# City number is 122 & city name is ilulissat
# City number is 123 & city name is nikolskoye
# City number is 124 & city name is cabo san lucas
# City number is 125 & city name is umm kaddadah
# City number is 126 & city name is olean
# City number is 127 & city name is raga
# City number is 128 & city name is tsabong
# City not found
# City number is 130 & city name is sitka
# City number is 131 & city name is caceres
# City not found
# City number is 133 & city name is bubaque
# City number is 134 & city name is klaksvik
# City number is 135 & city name is honiara
# City number is 136 & city name is bredasdorp
# City number is 137 & city name is longyearbyen
# City number is 138 & city name is mehamn
# City number is 139 & city name is severo-kurilsk
# City number is 140 & city name is celestun
# City number is 141 & city name is centennial
# City number is 142 & city name is puerto escondido
# City number is 143 & city name is dikson
# City number is 144 & city name is saint george
# City number is 145 & city name is port-gentil
# City number is 146 & city name is fortuna
# City number is 147 & city name is bathsheba
# City number is 148 & city name is kieta
# City number is 149 & city name is san juan
# City number is 150 & city name is de-kastri
# City number is 151 & city name is rantepao
# City number is 152 & city name is carutapera
# City number is 153 & city name is alice springs
# City number is 154 & city name is diamantino
# City not found
# City number is 156 & city name is coahuayana
# City number is 157 & city name is sao joao da barra
# City number is 158 & city name is lavrentiya
# City number is 159 & city name is cockburn town
# City not found
# City number is 161 & city name is moron
# City number is 162 & city name is kahului
# City number is 163 & city name is bilibino
# City number is 164 & city name is balkanabat
# City number is 165 & city name is hamilton
# City number is 166 & city name is souillac
# City number is 167 & city name is xining
# City number is 168 & city name is craig
# City number is 169 & city name is dharchula
# City number is 170 & city name is tomatlan
# City number is 171 & city name is paamiut
# City number is 172 & city name is portland
# City not found
# City number is 174 & city name is ahipara
# City number is 175 & city name is lielvarde
# City number is 176 & city name is scarborough
# City number is 177 & city name is rabo de peixe
# City number is 178 & city name is arman
# City number is 179 & city name is bayreuth
# City number is 180 & city name is rio gallegos
# City number is 181 & city name is inhambane
# City number is 182 & city name is kailua
# City number is 183 & city name is hovd
# City number is 184 & city name is yerbogachen
# City not found
# City number is 186 & city name is rancho palos verdes
# City number is 187 & city name is general roca
# City number is 188 & city name is vrangel
# City number is 189 & city name is colac
# City number is 190 & city name is kismayo
# City number is 191 & city name is aitape
# City not found
# City number is 193 & city name is bichura
# City not found
# City number is 195 & city name is okakarara
# City number is 196 & city name is pacific grove
# City number is 197 & city name is hasaki
# City number is 198 & city name is bambous virieux
# City number is 199 & city name is bungoma
# City number is 200 & city name is ponta do sol
# City not found
# City number is 202 & city name is mocuba
# City number is 203 & city name is codrington
# City number is 204 & city name is hualmay
# City number is 205 & city name is kayes
# City not found
# City number is 207 & city name is turayf
# City number is 208 & city name is ketchikan
# City not found
# City number is 210 & city name is nosy varika
# City number is 211 & city name is lasa
# City number is 212 & city name is tiksi
# City number is 213 & city name is ossora
# City number is 214 & city name is coquimbo
# City number is 215 & city name is corinto
# City number is 216 & city name is northam
# City number is 217 & city name is kapaa
# City number is 218 & city name is iwaki
# City number is 219 & city name is san cristobal
# City number is 220 & city name is laguna
# City number is 221 & city name is batagay-alyta
# City not found
# City number is 223 & city name is vryburg
# City number is 224 & city name is vila franca do campo
# City number is 225 & city name is touros
# City number is 226 & city name is aleksandrovskoye
# City number is 227 & city name is seoul
# City number is 228 & city name is payson
# City number is 229 & city name is upernavik
# City number is 230 & city name is evensk
# City number is 231 & city name is lebu
# City number is 232 & city name is cap malheureux
# City number is 233 & city name is price
# City number is 234 & city name is madimba
# City number is 235 & city name is santa rosa
# City number is 236 & city name is yar-sale
# City number is 237 & city name is warrnambool
# City number is 238 & city name is dunedin
# City number is 239 & city name is clyde river
# City number is 240 & city name is esna
# City number is 241 & city name is flinders
# City number is 242 & city name is saldanha
# City number is 243 & city name is kibre mengist
# City number is 244 & city name is denpasar
# City number is 245 & city name is srednekolymsk
# City number is 246 & city name is faanui
# City number is 247 & city name is pontianak
# City number is 248 & city name is ukiah
# City number is 249 & city name is toledo
# City number is 250 & city name is kavieng
# City number is 251 & city name is neuquen
# City number is 252 & city name is port elizabeth
# City number is 253 & city name is aksu
# City number is 254 & city name is puerto baquerizo moreno
# City number is 255 & city name is anadyr
# City number is 256 & city name is terney
# City number is 257 & city name is gushikawa
# City number is 258 & city name is la ronge
# City number is 259 & city name is aklavik
# City number is 260 & city name is kobayashi
# City number is 261 & city name is pisco
# City number is 262 & city name is karonga
# City number is 263 & city name is grand gaube
# City number is 264 & city name is tuktoyaktuk
# City number is 265 & city name is nishihara
# City number is 266 & city name is geraldton
# City not found
# City number is 268 & city name is victoria
# City number is 269 & city name is penzance
# City number is 270 & city name is nouadhibou
# City number is 271 & city name is sarab
# City not found
# City number is 273 & city name is tagusao
# City number is 274 & city name is adrar
# City number is 275 & city name is sampit
# City number is 276 & city name is komsomolskiy
# City number is 277 & city name is cayenne
# City number is 278 & city name is kilinochchi
# City number is 279 & city name is charters towers
# City number is 280 & city name is mombetsu
# City number is 281 & city name is kobryn
# City number is 282 & city name is byron bay
# City number is 283 & city name is sungaipenuh
# City number is 284 & city name is belaya gora
# City number is 285 & city name is porteirinha
# City number is 286 & city name is tura
# City number is 287 & city name is shakiso
# City number is 288 & city name is ust-kuyga
# City number is 289 & city name is kuytun
# City number is 290 & city name is bengkulu
# City number is 291 & city name is westport
# City number is 292 & city name is nabire
# City number is 293 & city name is kruisfontein
# City number is 294 & city name is zheleznodorozhnyy
# City number is 295 & city name is zyryanka
# City number is 296 & city name is apache junction
# City number is 297 & city name is shimoda
# City number is 298 & city name is kirakira
# City number is 299 & city name is lazarev
# City number is 300 & city name is jumla
# City number is 301 & city name is lujan
# City number is 302 & city name is koboko
# City number is 303 & city name is port blair
# City number is 304 & city name is terrace
# City number is 305 & city name is te anau
# City not found
# City number is 307 & city name is karratha
# City number is 308 & city name is qaqortoq
# City number is 309 & city name is tual
# City number is 310 & city name is dingzhou
# City number is 311 & city name is vestmannaeyjar
# City number is 312 & city name is taoudenni
# City number is 313 & city name is krasnoselkup
# City number is 314 & city name is shirokovskiy
# City number is 315 & city name is tessalit
# City number is 316 & city name is gamba
# City number is 317 & city name is manokwari
# City number is 318 & city name is berezanka
# City number is 319 & city name is miri
# City not found
# City number is 321 & city name is mogadishu
# City number is 322 & city name is lengshuitan
# City not found
# City number is 324 & city name is tahta
# City number is 325 & city name is surab
# City number is 326 & city name is kulhudhuffushi
# City number is 327 & city name is umm lajj
# City number is 328 & city name is yuancheng
# City not found
# City number is 330 & city name is san patricio
# City not found
# City number is 332 & city name is novaya ladoga
# City number is 333 & city name is tucuman
# City number is 334 & city name is skibbereen
# City number is 335 & city name is salalah
# City number is 336 & city name is matagami
# City number is 337 & city name is muscat
# City number is 338 & city name is filadelfia
# City number is 339 & city name is krasnyy yar
# City number is 340 & city name is ambilobe
# City number is 341 & city name is yurty
# City number is 342 & city name is copala
# City not found
# City number is 344 & city name is oriximina
# City number is 345 & city name is cherskiy
# City number is 346 & city name is west bay
# City number is 347 & city name is peniche
# City number is 348 & city name is vao
# City number is 349 & city name is burkburnett
# City number is 350 & city name is gorom-gorom
# City number is 351 & city name is brae
# City number is 352 & city name is carahue
# City not found
# City number is 354 & city name is jacareacanga
# City number is 355 & city name is micomeseng
# City number is 356 & city name is itarema
# City not found
# City number is 358 & city name is kloulklubed
# City number is 359 & city name is vuktyl
# City number is 360 & city name is bismarck
# City number is 361 & city name is sistranda
# City number is 362 & city name is ndele
# City number is 363 & city name is batagay
# City number is 364 & city name is iqaluit
# City number is 365 & city name is wawa
# City number is 366 & city name is dali
# City not found
# City number is 368 & city name is xiongzhou
# City number is 369 & city name is suez
# City number is 370 & city name is traverse city
# City number is 371 & city name is beyneu
# City number is 372 & city name is sibolga
# City number is 373 & city name is cordoba
# City number is 374 & city name is urucara
# City number is 375 & city name is alofi
# City number is 376 & city name is balkhash
# City number is 377 & city name is coihaique
# City number is 378 & city name is damoh
# City number is 379 & city name is nanortalik
# City number is 380 & city name is havelock
# City number is 381 & city name is tuy hoa
# City number is 382 & city name is gizo
# City number is 383 & city name is wewak
# City not found
# City number is 385 & city name is whitehorse
# City number is 386 & city name is ferrol
# City number is 387 & city name is camocim
# City number is 388 & city name is luderitz
# City number is 389 & city name is mayo
# City number is 390 & city name is chuy
# City number is 391 & city name is fairbanks
# City number is 392 & city name is plettenberg bay
# City number is 393 & city name is margate
# City number is 394 & city name is eureka
# City number is 395 & city name is guiglo
# City number is 396 & city name is paramonga
# City number is 397 & city name is santa marinella
# City number is 398 & city name is verkhnyaya maksakovka
# City not found
# City number is 400 & city name is tomigusuku
# City number is 401 & city name is khasan
# City number is 402 & city name is hukuntsi
# City number is 403 & city name is madinat sittah uktubar
# City number is 404 & city name is mwinilunga
# City number is 405 & city name is knysna
# City number is 406 & city name is teahupoo
# City number is 407 & city name is antofagasta
# City number is 408 & city name is erenhot
# City number is 409 & city name is russell
# City number is 410 & city name is machilipatnam
# City not found
# City number is 412 & city name is bow island
# City number is 413 & city name is naze
# City number is 414 & city name is maarianhamina
# City number is 415 & city name is novoagansk
# City number is 416 & city name is puri
# City number is 417 & city name is safakulevo
# City number is 418 & city name is namibe
# City number is 419 & city name is dicabisagan
# City number is 420 & city name is sabha
# City number is 421 & city name is kenai
# City number is 422 & city name is vandra
# City number is 423 & city name is uyemskiy
# City number is 424 & city name is narsaq
# City number is 425 & city name is pokhara
# City number is 426 & city name is roslavl
# City number is 427 & city name is port macquarie
# City number is 428 & city name is dong hoi
# City number is 429 & city name is keti bandar
# City number is 430 & city name is takoradi
# City number is 431 & city name is hohhot
# City number is 432 & city name is bhachau
# City number is 433 & city name is port lincoln
# City number is 434 & city name is hit
# City number is 435 & city name is belmonte
# City number is 436 & city name is marystown
# City number is 437 & city name is shorapur
# City number is 438 & city name is saint-francois
# City number is 439 & city name is korem
# City not found
# City number is 441 & city name is chateaubelair
# City number is 442 & city name is tekeli
# City number is 443 & city name is vila velha
# City number is 444 & city name is tabas
# City number is 445 & city name is faya
# City number is 446 & city name is sechura
# City number is 447 & city name is thunder bay
# City number is 448 & city name is santiago
# City number is 449 & city name is ndungu
# City number is 450 & city name is olafsvik
# City number is 451 & city name is spring hill
# City number is 452 & city name is dzaoudzi
# City not found
# City number is 454 & city name is kurchum
# City number is 455 & city name is zhezkazgan
# City number is 456 & city name is la crosse
# City not found
# City number is 458 & city name is ugoofaaru
# City number is 459 & city name is okhotsk
# City number is 460 & city name is golden
# City number is 461 & city name is samarai
# City number is 462 & city name is shepetivka
# City number is 463 & city name is hambantota
# City number is 464 & city name is maniitsoq
# City number is 465 & city name is warwick
# City number is 466 & city name is alekseyevka
# City number is 467 & city name is buchanan
# City number is 468 & city name is xuddur
# City number is 469 & city name is swan river
# City number is 470 & city name is antigonish
# City number is 471 & city name is satipo
# City number is 472 & city name is gummidipundi
# City number is 473 & city name is husavik
# City number is 474 & city name is tefe
# City number is 475 & city name is vasilevo
# City number is 476 & city name is maceio
# City number is 477 & city name is almeirim
# City number is 478 & city name is vozhega
# City number is 479 & city name is grindavik
# City number is 480 & city name is vilyuysk
# City number is 481 & city name is broome
# City number is 482 & city name is caravelas
# City number is 483 & city name is tommot
# City number is 484 & city name is kamenka
# City number is 485 & city name is taltal
# City number is 486 & city name is makakilo city
# City number is 487 & city name is matara
# City number is 488 & city name is san carlos de bariloche
# City not found
# City number is 490 & city name is qasigiannguit
# City number is 491 & city name is naron
# City number is 492 & city name is mount isa
# City not found
# City number is 494 & city name is nyurba
# City number is 495 & city name is tecpan
# City number is 496 & city name is bolgatanga
# City number is 497 & city name is saint-augustin
# City number is 498 & city name is fort nelson
# City number is 499 & city name is manaus
# City number is 500 & city name is baykit
# City number is 501 & city name is itanhaem
# City number is 502 & city name is egvekinot
# City number is 503 & city name is susanville
# City number is 504 & city name is rocha
# City number is 505 & city name is winchester
# City number is 506 & city name is sri aman
# City number is 507 & city name is mackenzie
# City number is 508 & city name is ancud
# City number is 509 & city name is york
# City number is 510 & city name is pinsk
# City number is 511 & city name is port hardy
# City number is 512 & city name is narrabri
# City number is 513 & city name is viedma
# City number is 514 & city name is beringovskiy
# City number is 515 & city name is soure
# City number is 516 & city name is weligama
# City number is 517 & city name is la peca
# City number is 518 & city name is mantua
# City number is 519 & city name is poum
# City number is 520 & city name is hayrabolu
# City number is 521 & city name is bremerton
# City number is 522 & city name is zorritos
# City number is 523 & city name is sorong
# City not found
# City number is 525 & city name is sisimiut
# City number is 526 & city name is kyzyl-oktyabr
# City number is 527 & city name is solhan
# City number is 528 & city name is punta alta
# City number is 529 & city name is kitob
# City number is 530 & city name is gravdal
# City number is 531 & city name is muttupet
# City number is 532 & city name is emerald
# City number is 533 & city name is ardahan
# City number is 534 & city name is axim
# City number is 535 & city name is salinas
# City number is 536 & city name is bourail
# City number is 537 & city name is quatre cocos
# City not found
# City number is 539 & city name is tateyama
# City number is 540 & city name is migori
# City number is 541 & city name is dunmore town
# City number is 542 & city name is moree
# City number is 543 & city name is shawville
# City number is 544 & city name is savannah bight
# City number is 545 & city name is menomonie
# City number is 546 & city name is taclobo
# City number is 547 & city name is los llanos de aridane
# City number is 548 & city name is tres lagoas
# City number is 549 & city name is baoqing
# City number is 550 & city name is dongtai
# City number is 551 & city name is vila
# City number is 552 & city name is soria
# City number is 553 & city name is alibag
# City number is 554 & city name is nuuk
# City number is 555 & city name is san ignacio
# City number is 556 & city name is okaihau
# City number is 557 & city name is moa
# City number is 558 & city name is alcains
# City number is 559 & city name is abong mbang
# City number is 560 & city name is meulaboh
# City number is 561 & city name is tautira
# City number is 562 & city name is aswan
# City number is 563 & city name is pimenta bueno
# City number is 564 & city name is novobiryusinskiy
# City not found
# City number is 566 & city name is murray bridge
# City number is 567 & city name is ofunato
# City number is 568 & city name is belomorsk
# City number is 569 & city name is bogalusa
# City number is 570 & city name is belem de sao francisco
# City not found
# City number is 572 & city name is padang
# City number is 573 & city name is goderich
# City number is 574 & city name is porto walter
# City number is 575 & city name is kilimatinde
# City number is 576 & city name is tovste
# City number is 577 & city name is bilma
# City not found

# %%
#Create DataFrame
weather_df = pd.DataFrame({"City": city_name, "Lat": lat, "Lng": long,
                           "Max Temp": max_temp, "Humidity": humidity,
                           "Cloudiness": cloudiness, "Wind Speed": wind,
                           "Country": country, "Date": date})
weather_df
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     provideniya  64.38 -173.30    282.15       100          90        3.00
# 1          hobart -42.88  147.33    281.48        65          40        1.00
# 2      chokurdakh  70.63  147.92    279.39        71          55        4.37
# 3         mataura -46.19  168.86    282.18        84         100        1.76
# 4        cabedelo  -6.98  -34.83    297.15        88          75        4.60
# ..            ...    ...     ...       ...       ...         ...         ...
# 518      goderich  43.75  -81.72    297.59        76           0        2.31
# 519  porto walter  -8.27  -72.74    304.62        51          92        1.06
# 520   kilimatinde  -5.85   34.95    291.50        71          39        2.57
# 521        tovste  48.85   25.73    294.82        79          52        1.88
# 522         bilma  18.69   12.92    308.65        15          82        0.46
#
#     Country        Date
# 0        RU  1596054141
# 1        AU  1596053898
# 2        RU  1596054136
# 3        NZ  1596054137
# 4        BR  1596054164
# ..      ...         ...
# 518      CA  1596054672
# 519      BR  1596054673
# 520      TZ  1596054673
# 521      UA  1596054673
# 522      NE  1596054673
#
# [523 rows x 9 columns]

# %%
#Check which cities have humidity . 100%
humidity_df = weather_df.loc[weather_df["Humidity"] > 100]
humidity_df
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
#Export DataFrame to CSV
weather_df.to_csv("output_data/cities.csv")

# %% [markdown]
# # Latitude vs. Temperature Plot

# %%
x = lat
y = max_temp

plt.scatter(lat, max_temp, marker="o", facecolors="lightblue", edgecolors="black")

#Add title and other labels
plt.title("City Latitude vs. Max Temperature (07/29/2020)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.show()

# %% [markdown]
# # Latitude vs. Humidity Plot

# %%
x = lat
y = humidity

plt.scatter(lat, humidity, marker="o", facecolors="lightblue", edgecolors="black")

#Add title and other labels
plt.title("City Latitude vs. humidity (07/29/2020)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.show()

# %% [markdown]
# # Latitude vs. Cloudiness Plot

# %%
x = lat
y = cloudiness

plt.scatter(lat, cloudiness, marker="o", facecolors="lightblue", edgecolors="black")

#Add title and other labels
plt.title("City Latitude vs. Cloudiness (07/29/2020)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.show()

# %% [markdown]
# # Latitude vs. Wind Speed Plot

# %%
x = lat
y = wind

plt.scatter(lat, wind, marker="o", facecolors="lightblue", edgecolors="black")

#Add title and other labels
plt.title("City Latitude vs. Wind Speed (07/29/2020)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.show()
