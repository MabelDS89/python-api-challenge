# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
import requests

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 637

# %%
#Perform API calls
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"

# Build query URL
query_url = url + "appid=" + weather_api_key + "&q=" + city

# Get weather data
weather_response = requests.get(query_url)
weather_json = weather_response.json()
print(weather_json)
# Out:
# {'coord': {'lon': -139.03, 'lat': -9.8}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 299.17, 'feels_like': 297.27, 'temp_min': 299.17, 'temp_max': 299.17, 'pressure': 1011, 'humidity': 75, 'sea_level': 1011, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 8.86, 'deg': 90}, 'rain': {'1h': 0.17}, 'clouds': {'all': 6}, 'dt': 1596065448, 'sys': {'country': 'PF', 'sunrise': 1596036732, 'sunset': 1596078764}, 'timezone': -34200, 'id': 4020109, 'name': 'Atuona', 'cod': 200}

# %%
#Use a for loop to go through cities
#Use try and except for going through cities
query_url = url + "appid=" + weather_api_key + "&q="

#either make a dictionary to store key(city) and its values
lat = []
long =[]
max_temp = []
humidity = []
cloudiness = []
wind = []
country = []
date = []

city_name = []

for index,city in enumerate(cities):
    #try and except error
    try:
        response = requests.get(query_url + city).json()
        lat.append(response["coord"]["lat"])
        long.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind.append(response["wind"]["speed"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        city_name.append(city)
        print("City number is " + str(index) + " & city name is " + city)
    except:
        print("City not found")
# Out:
# City number is 0 & city name is port hedland
# City number is 1 & city name is henties bay
# City not found
# City number is 3 & city name is cape town
# City number is 4 & city name is camalu
# City number is 5 & city name is tiksi
# City number is 6 & city name is bluff
# City number is 7 & city name is saint anthony
# City number is 8 & city name is castelnaudary
# City number is 9 & city name is new norfolk
# City number is 10 & city name is saskylakh
# City number is 11 & city name is karasjok
# City number is 12 & city name is busselton
# City number is 13 & city name is mahebourg
# City number is 14 & city name is nueva loja
# City number is 15 & city name is pevek
# City number is 16 & city name is hobart
# City number is 17 & city name is ushuaia
# City number is 18 & city name is margate
# City number is 19 & city name is hasaki
# City number is 20 & city name is bambous virieux
# City number is 21 & city name is punta arenas
# City number is 22 & city name is arraial do cabo
# City number is 23 & city name is airai
# City number is 24 & city name is karratha
# City number is 25 & city name is majene
# City number is 26 & city name is amuntai
# City number is 27 & city name is rawson
# City not found
# City number is 29 & city name is avarua
# City number is 30 & city name is bengkulu
# City number is 31 & city name is nikolskoye
# City number is 32 & city name is san quintin
# City number is 33 & city name is dikson
# City number is 34 & city name is axim
# City number is 35 & city name is hermanus
# City number is 36 & city name is rodino
# City number is 37 & city name is jamestown
# City not found
# City number is 39 & city name is rikitea
# City not found
# City number is 41 & city name is fare
# City number is 42 & city name is carnarvon
# City number is 43 & city name is butaritari
# City number is 44 & city name is vaini
# City number is 45 & city name is awbari
# City number is 46 & city name is lamar
# City number is 47 & city name is souillac
# City number is 48 & city name is cabo san lucas
# City number is 49 & city name is merrill
# City number is 50 & city name is chuy
# City number is 51 & city name is hambantota
# City not found
# City number is 53 & city name is tasiilaq
# City number is 54 & city name is shahdadkot
# City number is 55 & city name is mataura
# City number is 56 & city name is port alfred
# City number is 57 & city name is mountain home
# City number is 58 & city name is port lincoln
# City number is 59 & city name is visby
# City number is 60 & city name is kaitangata
# City number is 61 & city name is ust-kuyga
# City number is 62 & city name is kano
# City number is 63 & city name is mackay
# City number is 64 & city name is albany
# City number is 65 & city name is tuatapere
# City number is 66 & city name is pemba
# City number is 67 & city name is qaanaaq
# City number is 68 & city name is komsomolskiy
# City number is 69 & city name is inhambane
# City number is 70 & city name is torbay
# City number is 71 & city name is saint george
# City number is 72 & city name is chokurdakh
# City number is 73 & city name is suntar
# City number is 74 & city name is tuktoyaktuk
# City number is 75 & city name is ribeira grande
# City number is 76 & city name is pochutla
# City number is 77 & city name is san cristobal
# City number is 78 & city name is bathsheba
# City number is 79 & city name is kapaa
# City number is 80 & city name is usinsk
# City number is 81 & city name is san carlos de bariloche
# City number is 82 & city name is bonthe
# City number is 83 & city name is chicama
# City number is 84 & city name is bilma
# City number is 85 & city name is rayong
# City number is 86 & city name is kavieng
# City number is 87 & city name is murwara
# City number is 88 & city name is flinders
# City number is 89 & city name is fairbanks
# City number is 90 & city name is klaksvik
# City number is 91 & city name is yellowknife
# City number is 92 & city name is prescott valley
# City number is 93 & city name is te anau
# City number is 94 & city name is bara
# City number is 95 & city name is olafsvik
# City number is 96 & city name is nadym
# City number is 97 & city name is cherskiy
# City not found
# City number is 99 & city name is bredasdorp
# City number is 100 & city name is manati
# City number is 101 & city name is valdivia
# City number is 102 & city name is puerto ayora
# City number is 103 & city name is esperance
# City number is 104 & city name is ozernovskiy
# City number is 105 & city name is khatanga
# City number is 106 & city name is the pas
# City number is 107 & city name is eldoret
# City number is 108 & city name is laguna
# City number is 109 & city name is alice springs
# City number is 110 & city name is acarau
# City number is 111 & city name is faanui
# City number is 112 & city name is hilo
# City number is 113 & city name is sarangani
# City number is 114 & city name is hobyo
# City number is 115 & city name is thompson
# City number is 116 & city name is todos santos
# City number is 117 & city name is fort nelson
# City number is 118 & city name is royan
# City number is 119 & city name is mount gambier
# City number is 120 & city name is praia da vitoria
# City number is 121 & city name is severo-kurilsk
# City number is 122 & city name is senneterre
# City number is 123 & city name is lagoa
# City number is 124 & city name is mar del plata
# City number is 125 & city name is lincoln
# City number is 126 & city name is putatan
# City not found
# City number is 128 & city name is jacareacanga
# City number is 129 & city name is muncar
# City number is 130 & city name is yumen
# City number is 131 & city name is castro
# City number is 132 & city name is ritchie
# City number is 133 & city name is aksu
# City number is 134 & city name is kinkala
# City number is 135 & city name is puerto quijarro
# City number is 136 & city name is iralaya
# City not found
# City not found
# City number is 139 & city name is codrington
# City number is 140 & city name is veraval
# City number is 141 & city name is itoman
# City number is 142 & city name is ko samui
# City number is 143 & city name is ceres
# City number is 144 & city name is cintalapa
# City number is 145 & city name is iqaluit
# City number is 146 & city name is bethel
# City number is 147 & city name is puerto escondido
# City number is 148 & city name is lebu
# City number is 149 & city name is paamiut
# City number is 150 & city name is vrangel
# City number is 151 & city name is hithadhoo
# City number is 152 & city name is cascais
# City number is 153 & city name is masallatah
# City number is 154 & city name is la libertad
# City number is 155 & city name is cidreira
# City number is 156 & city name is dingle
# City number is 157 & city name is snyder
# City number is 158 & city name is saint-georges
# City number is 159 & city name is horki
# City number is 160 & city name is nyurba
# City number is 161 & city name is villamontes
# City number is 162 & city name is riyadh
# City number is 163 & city name is sivaki
# City number is 164 & city name is yulara
# City number is 165 & city name is zhezkazgan
# City number is 166 & city name is neuquen
# City number is 167 & city name is abeche
# City number is 168 & city name is ponta do sol
# City number is 169 & city name is ferrol
# City number is 170 & city name is lodwar
# City number is 171 & city name is port said
# City number is 172 & city name is ugoofaaru
# City number is 173 & city name is san miguel
# City not found
# City number is 175 & city name is igarka
# City number is 176 & city name is yar-sale
# City number is 177 & city name is harper
# City number is 178 & city name is broken hill
# City number is 179 & city name is labe
# City number is 180 & city name is omsukchan
# City number is 181 & city name is praia
# City number is 182 & city name is qujing
# City number is 183 & city name is malakal
# City number is 184 & city name is atuona
# City number is 185 & city name is kidal
# City number is 186 & city name is hede
# City number is 187 & city name is port hawkesbury
# City number is 188 & city name is altay
# City number is 189 & city name is sitka
# City number is 190 & city name is verkhoyansk
# City number is 191 & city name is vao
# City number is 192 & city name is bolkhov
# City number is 193 & city name is bandarbeyla
# City number is 194 & city name is mabaruma
# City number is 195 & city name is outjo
# City number is 196 & city name is provideniya
# City number is 197 & city name is solnechnyy
# City number is 198 & city name is salinas
# City number is 199 & city name is soller
# City not found
# City number is 201 & city name is lata
# City number is 202 & city name is saint-philippe
# City number is 203 & city name is orlik
# City number is 204 & city name is dakar
# City number is 205 & city name is shelburne
# City number is 206 & city name is puerto leguizamo
# City number is 207 & city name is chunhuhub
# City number is 208 & city name is tucuman
# City number is 209 & city name is horasan
# City number is 210 & city name is marsabit
# City number is 211 & city name is brae
# City number is 212 & city name is labuhan
# City number is 213 & city name is carutapera
# City number is 214 & city name is sioux lookout
# City number is 215 & city name is mutsu
# City number is 216 & city name is isangel
# City number is 217 & city name is ballina
# City number is 218 & city name is half moon bay
# City number is 219 & city name is vestmannaeyjar
# City number is 220 & city name is ancud
# City number is 221 & city name is fukue
# City number is 222 & city name is huilong
# City number is 223 & city name is namie
# City number is 224 & city name is srednekolymsk
# City number is 225 & city name is coihaique
# City not found
# City number is 227 & city name is honiara
# City number is 228 & city name is nome
# City number is 229 & city name is plettenberg bay
# City not found
# City number is 231 & city name is beloha
# City number is 232 & city name is mount isa
# City number is 233 & city name is port macquarie
# City number is 234 & city name is novobirilyussy
# City number is 235 & city name is kuybysheve
# City number is 236 & city name is fortuna
# City number is 237 & city name is juba
# City not found
# City number is 239 & city name is saint-augustin
# City number is 240 & city name is bintulu
# City number is 241 & city name is bilibino
# City number is 242 & city name is georgetown
# City number is 243 & city name is bolshoy lug
# City number is 244 & city name is sawakin
# City not found
# City number is 246 & city name is dali
# City not found
# City number is 248 & city name is batsfjord
# City number is 249 & city name is aklavik
# City number is 250 & city name is saint-pierre
# City number is 251 & city name is bhopal
# City number is 252 & city name is charlottesville
# City not found
# City not found
# City number is 255 & city name is comodoro rivadavia
# City number is 256 & city name is catuday
# City number is 257 & city name is madison heights
# City number is 258 & city name is clyde river
# City number is 259 & city name is ipixuna
# City number is 260 & city name is naze
# City number is 261 & city name is kahului
# City number is 262 & city name is sanmenxia
# City number is 263 & city name is rio grande
# City number is 264 & city name is roebourne
# City number is 265 & city name is sabzevar
# City number is 266 & city name is port elizabeth
# City number is 267 & city name is pedernales
# City number is 268 & city name is salalah
# City number is 269 & city name is la ronge
# City number is 270 & city name is ambon
# City not found
# City number is 272 & city name is shushenskoye
# City number is 273 & city name is lompoc
# City number is 274 & city name is meulaboh
# City number is 275 & city name is carmelo
# City number is 276 & city name is gizo
# City number is 277 & city name is seymchan
# City number is 278 & city name is constitucion
# City number is 279 & city name is xapuri
# City number is 280 & city name is east london
# City number is 281 & city name is lorengau
# City number is 282 & city name is lima
# City number is 283 & city name is peddapuram
# City number is 284 & city name is san mateo del mar
# City number is 285 & city name is fort abbas
# City number is 286 & city name is tortoli
# City number is 287 & city name is mataram
# City number is 288 & city name is jieshi
# City number is 289 & city name is nicoya
# City number is 290 & city name is nishihara
# City number is 291 & city name is kavaratti
# City number is 292 & city name is simpsonville
# City number is 293 & city name is paranhos
# City not found
# City number is 295 & city name is balsta
# City number is 296 & city name is aginskoye
# City number is 297 & city name is antalaha
# City not found
# City number is 299 & city name is murray bridge
# City number is 300 & city name is grindavik
# City number is 301 & city name is port-cartier
# City number is 302 & city name is houma
# City number is 303 & city name is mackenzie
# City number is 304 & city name is dalvik
# City number is 305 & city name is vanavara
# City number is 306 & city name is loandjili
# City not found
# City number is 308 & city name is kaohsiung
# City number is 309 & city name is deputatskiy
# City number is 310 & city name is ucluelet
# City number is 311 & city name is buchanan
# City number is 312 & city name is morgan city
# City not found
# City number is 314 & city name is copiapo
# City not found
# City number is 316 & city name is kodiak
# City number is 317 & city name is sao filipe
# City number is 318 & city name is iberia
# City number is 319 & city name is oktyabrskiy
# City number is 320 & city name is jian
# City number is 321 & city name is port blair
# City not found
# City number is 323 & city name is hualmay
# City number is 324 & city name is luanda
# City number is 325 & city name is cap-aux-meules
# City not found
# City number is 327 & city name is khasan
# City number is 328 & city name is olgod
# City not found
# City number is 330 & city name is walvis bay
# City number is 331 & city name is juneau
# City number is 332 & city name is masty
# City number is 333 & city name is katsuura
# City number is 334 & city name is leningradskiy
# City number is 335 & city name is kungurtug
# City number is 336 & city name is progreso
# City number is 337 & city name is kholm-zhirkovskiy
# City number is 338 & city name is porto novo
# City number is 339 & city name is nalut
# City number is 340 & city name is guliston
# City not found
# City number is 342 & city name is inuvik
# City not found
# City not found
# City number is 345 & city name is yakovlevka
# City number is 346 & city name is bermeo
# City not found
# City number is 348 & city name is norman wells
# City number is 349 & city name is san patricio
# City number is 350 & city name is mao
# City number is 351 & city name is playas
# City number is 352 & city name is ternate
# City number is 353 & city name is quelimane
# City number is 354 & city name is cayenne
# City number is 355 & city name is ekhabi
# City number is 356 & city name is wuan
# City number is 357 & city name is wairoa
# City number is 358 & city name is palu
# City number is 359 & city name is upernavik
# City number is 360 & city name is emerald
# City number is 361 & city name is kupang
# City number is 362 & city name is lumphat
# City number is 363 & city name is hofn
# City number is 364 & city name is harrison
# City number is 365 & city name is honningsvag
# City number is 366 & city name is longyearbyen
# City number is 367 & city name is los llanos de aridane
# City number is 368 & city name is tashtagol
# City number is 369 & city name is barrow
# City not found
# City number is 371 & city name is manadhoo
# City number is 372 & city name is nanortalik
# City number is 373 & city name is sola
# City number is 374 & city name is omboue
# City not found
# City number is 376 & city name is luderitz
# City number is 377 & city name is yaan
# City number is 378 & city name is atbasar
# City number is 379 & city name is armizonskoye
# City number is 380 & city name is bhagalpur
# City number is 381 & city name is bataipora
# City number is 382 & city name is talnakh
# City not found
# City number is 384 & city name is kirakira
# City number is 385 & city name is nixa
# City number is 386 & city name is antofagasta
# City number is 387 & city name is guacimo
# City number is 388 & city name is marawi
# City number is 389 & city name is namatanai
# City number is 390 & city name is bassar
# City number is 391 & city name is tisovec
# City number is 392 & city name is okha
# City number is 393 & city name is north myrtle beach
# City number is 394 & city name is mantua
# City number is 395 & city name is ankang
# City number is 396 & city name is redding
# City not found
# City number is 398 & city name is qidong
# City number is 399 & city name is beaverlodge
# City number is 400 & city name is banting
# City number is 401 & city name is wenchi
# City number is 402 & city name is prince rupert
# City number is 403 & city name is geetbets
# City number is 404 & city name is bunia
# City not found
# City number is 406 & city name is constantine
# City number is 407 & city name is almunecar
# City number is 408 & city name is tori
# City number is 409 & city name is bereda
# City number is 410 & city name is boyolangu
# City not found
# City number is 412 & city name is grand island
# City number is 413 & city name is vaitape
# City number is 414 & city name is mocuba
# City number is 415 & city name is muros
# City number is 416 & city name is pimenteiras
# City number is 417 & city name is mongo
# City not found
# City number is 419 & city name is nuuk
# City number is 420 & city name is ruidoso
# City number is 421 & city name is jinchang
# City number is 422 & city name is ca mau
# City number is 423 & city name is san rafael del sur
# City number is 424 & city name is parabel
# City number is 425 & city name is morwell
# City number is 426 & city name is tessalit
# City not found
# City number is 428 & city name is springdale
# City not found
# City number is 430 & city name is victoria
# City number is 431 & city name is aneby
# City number is 432 & city name is la romana
# City number is 433 & city name is safranbolu
# City number is 434 & city name is novaya ladoga
# City number is 435 & city name is santa fe
# City number is 436 & city name is caucaia
# City number is 437 & city name is tual
# City number is 438 & city name is pyapon
# City number is 439 & city name is karpathos
# City number is 440 & city name is yarada
# City number is 441 & city name is faya
# City number is 442 & city name is jalu
# City number is 443 & city name is fort morgan
# City number is 444 & city name is kichera
# City number is 445 & city name is lokosovo
# City number is 446 & city name is olinda
# City number is 447 & city name is tiznit
# City number is 448 & city name is shahr-e babak
# City number is 449 & city name is kichmengskiy gorodok
# City number is 450 & city name is wanning
# City number is 451 & city name is tilichiki
# City number is 452 & city name is flin flon
# City number is 453 & city name is trairi
# City not found
# City number is 455 & city name is irtyshskiy
# City number is 456 & city name is keetmanshoop
# City number is 457 & city name is rocha
# City number is 458 & city name is garowe
# City number is 459 & city name is at-bashi
# City number is 460 & city name is sangar
# City number is 461 & city name is kananga
# City number is 462 & city name is mehamn
# City not found
# City number is 464 & city name is alofi
# City number is 465 & city name is uniontown
# City not found
# City number is 467 & city name is taoudenni
# City number is 468 & city name is moquegua
# City number is 469 & city name is zyryanka
# City number is 470 & city name is vila franca do campo
# City number is 471 & city name is mitsamiouli
# City number is 472 & city name is biltine
# City number is 473 & city name is selenginsk
# City number is 474 & city name is kamenka
# City number is 475 & city name is sao jose da coroa grande
# City number is 476 & city name is avallon
# City not found
# City number is 478 & city name is san juan bautista
# City number is 479 & city name is oriximina
# City number is 480 & city name is ahuimanu
# City number is 481 & city name is okhotsk
# City number is 482 & city name is puerto cabezas
# City number is 483 & city name is soure
# City number is 484 & city name is nemuro
# City number is 485 & city name is faxinal
# City number is 486 & city name is eregli
# City number is 487 & city name is dudinka
# City number is 488 & city name is kalengwa
# City number is 489 & city name is midland
# City number is 490 & city name is husavik
# City number is 491 & city name is kemin
# City number is 492 & city name is kushima
# City number is 493 & city name is batemans bay
# City number is 494 & city name is la peca
# City number is 495 & city name is ryotsu
# City number is 496 & city name is maputo
# City number is 497 & city name is makushino
# City number is 498 & city name is sao luis de montes belos
# City number is 499 & city name is jasper
# City number is 500 & city name is starkville
# City number is 501 & city name is bairiki
# City number is 502 & city name is barinas
# City number is 503 & city name is agadez
# City number is 504 & city name is daur
# City number is 505 & city name is araouane
# City number is 506 & city name is luganville
# City number is 507 & city name is truth or consequences
# City number is 508 & city name is myaundzha
# City number is 509 & city name is ibra
# City number is 510 & city name is sibolga
# City number is 511 & city name is sur
# City number is 512 & city name is owensboro
# City number is 513 & city name is monrovia
# City number is 514 & city name is libenge
# City number is 515 & city name is aswan
# City number is 516 & city name is shimoda
# City number is 517 & city name is monticello
# City number is 518 & city name is baturaja
# City number is 519 & city name is bubaque
# City number is 520 & city name is amarante do maranhao
# City number is 521 & city name is taywarah
# City number is 522 & city name is sojat
# City number is 523 & city name is sungai padi
# City number is 524 & city name is lipari
# City not found
# City number is 526 & city name is saldanha
# City number is 527 & city name is raga
# City not found
# City number is 529 & city name is ahipara
# City number is 530 & city name is avera
# City number is 531 & city name is weligama
# City not found
# City number is 533 & city name is maltahohe
# City number is 534 & city name is litovko
# City number is 535 & city name is atar
# City number is 536 & city name is acajutiba
# City number is 537 & city name is assentoft
# City number is 538 & city name is guerande
# City number is 539 & city name is kijang
# City number is 540 & city name is chapais
# City number is 541 & city name is mosquera
# City number is 542 & city name is nusaybin
# City number is 543 & city name is yuancheng
# City number is 544 & city name is wukari
# City number is 545 & city name is padang
# City number is 546 & city name is middlebury
# City number is 547 & city name is kalaleh
# City number is 548 & city name is meiganga
# City number is 549 & city name is guerrero negro
# City not found
# City not found
# City number is 552 & city name is barabinsk
# City number is 553 & city name is camana
# City number is 554 & city name is bud
# City not found
# City number is 556 & city name is talara
# City number is 557 & city name is hervey bay
# City number is 558 & city name is hirara
# City number is 559 & city name is naliya
# City number is 560 & city name is sorland
# City number is 561 & city name is george town
# City not found
# City number is 563 & city name is petropavlovsk-kamchatskiy
# City number is 564 & city name is bose
# City number is 565 & city name is san luis
# City number is 566 & city name is aksha
# City not found
# City number is 568 & city name is duncan
# City number is 569 & city name is sao joao do paraiso
# City number is 570 & city name is kochevo
# City number is 571 & city name is campbell river
# City number is 572 & city name is puerto baquerizo moreno
# City number is 573 & city name is tongren
# City number is 574 & city name is teya
# City number is 575 & city name is lasa
# City number is 576 & city name is konya
# City number is 577 & city name is richards bay
# City number is 578 & city name is jaisalmer
# City number is 579 & city name is northam
# City number is 580 & city name is maningrida
# City number is 581 & city name is yerbogachen
# City number is 582 & city name is mayumba
# City number is 583 & city name is punalur
# City number is 584 & city name is cockburn town
# City number is 585 & city name is serebryansk
# City number is 586 & city name is barzas
# City number is 587 & city name is elko
# City number is 588 & city name is shirgaon
# City number is 589 & city name is encamp
# City number is 590 & city name is lake havasu city
# City number is 591 & city name is guilin
# City number is 592 & city name is big spring
# City number is 593 & city name is geraldton
# City number is 594 & city name is caldwell
# City number is 595 & city name is tishchenskoye
# City number is 596 & city name is bela
# City number is 597 & city name is waipawa
# City number is 598 & city name is batagay
# City number is 599 & city name is yaqui
# City not found
# City not found
# City number is 602 & city name is narasannapeta
# City number is 603 & city name is carballo
# City number is 604 & city name is adrar
# City number is 605 & city name is rapid valley
# City number is 606 & city name is sao geraldo do araguaia
# City number is 607 & city name is yueyang
# City number is 608 & city name is nouadhibou
# City number is 609 & city name is muscle shoals
# City number is 610 & city name is lavrentiya
# City number is 611 & city name is havelock
# City number is 612 & city name is gazojak
# City number is 613 & city name is ilulissat
# City number is 614 & city name is mecca
# City number is 615 & city name is maebaru
# City number is 616 & city name is tabou
# City number is 617 & city name is wad rawah
# City number is 618 & city name is necochea
# City number is 619 & city name is ushibuka
# City number is 620 & city name is dunedin
# City number is 621 & city name is okitipupa
# City number is 622 & city name is ulaangom
# City number is 623 & city name is cloppenburg
# City number is 624 & city name is gutierrez
# City number is 625 & city name is kautokeino
# City number is 626 & city name is isabela
# City not found
# City number is 628 & city name is karlsfeld
# City number is 629 & city name is yakeshi
# City number is 630 & city name is sinnamary
# City not found
# City number is 632 & city name is ballia
# City number is 633 & city name is shalya
# City number is 634 & city name is baymak
# City number is 635 & city name is abu kamal
# City number is 636 & city name is muli

# %%
#Create DataFrame
weather_df = pd.DataFrame({"City": city_name, "Lat": lat, "Lng": long,
                           "Max Temp": max_temp, "Humidity": humidity,
                           "Cloudiness": cloudiness, "Wind Speed": wind,
                           "Country": country, "Date": date})
weather_df
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    port hedland -20.32  118.57    285.15        31           0        2.10
# 1     henties bay -22.12   14.28    286.48        90           0        3.15
# 2       cape town -33.93   18.42    286.48       100          40        3.10
# 3          camalu  30.85 -116.07    301.48        37          11        2.24
# 4           tiksi  71.69  128.87    277.59        86         100        3.78
# ..            ...    ...     ...       ...       ...         ...         ...
# 576        ballia  25.76   84.15    301.41        80         100        2.24
# 577        shalya  57.25   58.73    287.16        97         100        2.50
# 578        baymak  52.59   58.32    286.07        84           5        1.74
# 579     abu kamal  34.45   40.92    306.95        16           0        5.16
# 580          muli   2.92   73.57    301.52        75          95        7.75
#
#     Country        Date
# 0        AU  1596065461
# 1        NA  1596065461
# 2        ZA  1596065231
# 3        MX  1596065461
# 4        RU  1596065461
# ..      ...         ...
# 576      IN  1596065547
# 577      RU  1596065548
# 578      RU  1596065548
# 579      SY  1596065548
# 580      MV  1596065548
#
# [581 rows x 9 columns]

# %%
#Check which cities have humidity > 100%
humidity_df = weather_df.loc[weather_df["Humidity"] > 100]
humidity_df
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %% [markdown]
# There are no cities with humidity > 100%.

# %%
#Export DataFrame to CSV
weather_df.to_csv("output_data/cities.csv")

# %% [markdown]
# # Latitude vs. Temperature Plot

# %%
x = lat
y = max_temp

plt.scatter(lat, max_temp, marker="o", facecolors="lightblue", edgecolors="black")

#Add title and other labels
plt.title("City Latitude vs. Max Temperature (07/29/2020)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.savefig("output_data/Lat_Temp_Plot.png")
plt.show()

# %% [markdown]
# The Latitude vs. Temperature plot shows...

# %% [markdown]
# # Latitude vs. Humidity Plot

# %%
x = lat
y = humidity

plt.scatter(lat, humidity, marker="o", facecolors="lightblue", edgecolors="black")

#Add title and other labels
plt.title("City Latitude vs. humidity (07/29/2020)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.savefig("output_data/Lat_Humidity_Plot.png")
plt.show()

# %% [markdown]
# The Latitude vs. Humidity plot shows ...

# %% [markdown]
# # Latitude vs. Cloudiness Plot

# %%
x = lat
y = cloudiness

plt.scatter(lat, cloudiness, marker="o", facecolors="lightblue", edgecolors="black")

#Add title and other labels
plt.title("City Latitude vs. Cloudiness (07/29/2020)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.savefig("output_data/Lat_Cloudiness_Plot.png")
plt.show()

# %% [markdown]
# The Latitude vs. Cloudiness plot shows...

# %% [markdown]
# # Latitude vs. Wind Speed Plot

# %%
x = lat
y = wind

plt.scatter(lat, wind, marker="o", facecolors="lightblue", edgecolors="black")

#Add title and other labels
plt.title("City Latitude vs. Wind Speed (07/29/2020)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.savefig("output_data/Lat_Wind_Plot.png")
plt.show()

# %% [markdown]
# The Latitude vs. Wind Speed plot shows...

# %% [markdown]
# # LINEAR REGRESSIONS

# %%
#Create Northern Hemisphere DataFrames
northern_df = weather_df.loc[weather_df["Lat"] >= 0]
northern_df
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 3           camalu  30.85 -116.07    301.48        37          11        2.24
# 4            tiksi  71.69  128.87    277.59        86         100        3.78
# 6    saint anthony  45.02  -93.22    301.15        44           1        3.60
# 7    castelnaudary  43.32    1.95    297.15        73           3        1.50
# 9        saskylakh  71.92  114.08    286.42        63           0        1.66
# ..             ...    ...     ...       ...       ...         ...         ...
# 576         ballia  25.76   84.15    301.41        80         100        2.24
# 577         shalya  57.25   58.73    287.16        97         100        2.50
# 578         baymak  52.59   58.32    286.07        84           5        1.74
# 579      abu kamal  34.45   40.92    306.95        16           0        5.16
# 580           muli   2.92   73.57    301.52        75          95        7.75
#
#     Country        Date
# 3        MX  1596065461
# 4        RU  1596065461
# 6        US  1596065267
# 7        FR  1596065462
# 9        RU  1596065462
# ..      ...         ...
# 576      IN  1596065547
# 577      RU  1596065548
# 578      RU  1596065548
# 579      SY  1596065548
# 580      MV  1596065548
#
# [417 rows x 9 columns]

# %%
#Create Southern Hemisphere DataFrames
southern_df = weather_df.loc[weather_df["Lat"] <= 0]
southern_df
# Out:
#                         City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0               port hedland -20.32  118.57    285.15        31           0
# 1                henties bay -22.12   14.28    286.48        90           0
# 2                  cape town -33.93   18.42    286.48       100          40
# 5                      bluff -46.60  168.33    285.05        72         100
# 8                new norfolk -42.78  147.06    283.15        78          16
# ..                       ...    ...     ...       ...       ...         ...
# 541                geraldton -28.77  114.60    282.15        81           0
# 545                  waipawa -41.41  175.52    286.15        76           2
# 552  sao geraldo do araguaia  -6.40  -48.55    299.69        40          24
# 564                 necochea -38.55  -58.74    277.04        90          15
# 566                  dunedin -45.87  170.50    283.15        71          99
#
#      Wind Speed Country        Date
# 0          2.10      AU  1596065461
# 1          3.15      NA  1596065461
# 2          3.10      ZA  1596065231
# 5          5.57      NZ  1596065247
# 8          0.45      AU  1596065462
# ..          ...     ...         ...
# 541        3.60      AU  1596065541
# 545        7.20      NZ  1596065333
# 552        1.21      BR  1596065543
# 564        1.79      AR  1596065544
# 566        3.58      NZ  1596065450
#
# [164 rows x 9 columns]

# %% [markdown]
# # Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northern_df["Lat"]
y_values = northern_df["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values, marker="o", facecolors="lightblue", edgecolors="black")

plt.plot(x_values,regress_values,"r-")

plt.annotate(line_eq,(0,280),fontsize=15,color="red") 

#Add title and other labels
plt.title("Northern Hemisphere: City Latitude vs. Max Temperature (07/29/2020)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Show and save plot
plt.savefig("output_data/North_Lat_Temp_Plot.png")
plt.show()
# Out:
# The r-squared is: 0.42650000029675084

# %% [markdown]
# # Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_df["Lat"]
y_values = southern_df["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values, marker="o", facecolors="lightblue", edgecolors="black")

plt.plot(x_values,regress_values,"r-")

plt.annotate(line_eq,(-30,275),fontsize=15,color="red")

#Add title and other labels
plt.title("Southern Hemisphere: City Latitude vs. Max Temperature (07/29/2020)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Show and save plot
plt.savefig("output_data/South_Lat_Temp_Plot.png")
plt.show()
# Out:
# The r-squared is: 0.6785123671770937

# %% [markdown]
# # Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_df["Lat"]
y_values = northern_df["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values, marker="o", facecolors="lightblue", edgecolors="black")

plt.plot(x_values,regress_values,"r-")

plt.annotate(line_eq,(45,15),fontsize=15,color="red")

#Add title and other labels
plt.title("Northern Hemisphere: City Latitude vs. Humidity (07/29/2020)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Show and save plot
plt.savefig("output_data/North_Lat_Humidity_Plot.png")
plt.show()
# Out:
# The r-squared is: 0.0023256275312173416

# %% [markdown]
# # Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_df["Lat"]
y_values = southern_df["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values, marker="o", facecolors="lightblue", edgecolors="black")

plt.plot(x_values,regress_values,"r-")

plt.annotate(line_eq,(-55,30),fontsize=15,color="red")

#Add title and other labels
plt.title("Southern Hemisphere: City Latitude vs. Humidity (07/29/2020)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Show and save plot
plt.savefig("output_data/South_Lat_Humidity_Plot.png")
plt.show()
# Out:
# The r-squared is: 0.002121315704523466

# %% [markdown]
# # Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_df["Lat"]
y_values = northern_df["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values, marker="o", facecolors="lightblue", edgecolors="black")

plt.plot(x_values,regress_values,"r-")

plt.annotate(line_eq,(45,30),fontsize=15,color="red")

#Add title and other labels
plt.title("Northern Hemisphere: City Latitude vs. Cloudiness (07/29/2020)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Show and save plot
plt.savefig("output_data/North_Lat_Cloudiness_Plot.png")
plt.show()
# Out:
# The r-squared is: 0.008652456324573772

# %% [markdown]
# # Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_df["Lat"]
y_values = southern_df["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values, marker="o", facecolors="lightblue", edgecolors="black")

plt.plot(x_values,regress_values,"r-")

plt.annotate(line_eq,(-50,30),fontsize=15,color="red")

#Add title and other labels
plt.title("Southern Hemisphere: City Latitude vs. Cloudiness (07/29/2020)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Show and save plot
plt.savefig("output_data/South_Lat_Cloudiness_Plot.png")
plt.show()
# Out:
# The r-squared is: 2.623082353038116e-08

# %% [markdown]
# # Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_df["Lat"]
y_values = northern_df["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values, marker="o", facecolors="lightblue", edgecolors="black")

plt.plot(x_values,regress_values,"r-")

plt.annotate(line_eq,(0,11),fontsize=15,color="red")

#Add title and other labels
plt.title("Southern Hemisphere: City Latitude vs. Wind Speed (07/29/2020)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Show and save plot
plt.savefig("output_data/North_Lat_Wind_Plot.png")
plt.show()
# Out:
# The r-squared is: 0.005333872154692021

# %% [markdown]
# # Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_df["Lat"]
y_values = southern_df["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values, marker="o", facecolors="lightblue", edgecolors="black")

plt.plot(x_values,regress_values,"r-")

plt.annotate(line_eq,(-50,8),fontsize=15,color="red")

#Add title and other labels
plt.title("Southern Hemisphere: City Latitude vs. Wind Speed (07/29/2020)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Show and save plot
plt.savefig("output_data/South_Lat_Wind_Plot.png")
plt.show()
# Out:
# The r-squared is: 0.0019320262377984828
